# %%
from langgraph.graph import StateGraph,START, END
from typing import TypedDict, Literal, Annotated
from langchain_core.messages import SystemMessage, HumanMessage
import operator
from google import genai

# %%
GOOGLE_API_KEY="AIzaSyAc5FTk5ADwcF454_XJ8TNK7ZJHKdFjduk"
client = genai.Client(api_key=GOOGLE_API_KEY)

# %%
# response = client.models.generate_content(
#     model="gemini-2.5-flash",
#     contents={ "Write a poem about a cat and a dog that are friends."},
# )


def generate_text(prompt: str) -> str:
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents={ prompt },
    )
    return response.text

class GraphState(TypedDict):
        input: str
        output: str

def generate_text_node(state: GraphState) -> GraphState:
        prompt = state["input"]
        output = generate_text(prompt)
        return {"input": prompt, "output": output}

graph = StateGraph(GraphState)
graph.add_node("generate_text", generate_text_node)
graph.set_entry_point("generate_text")
graph.add_edge("generate_text", END)


app= graph.compile()
    
response = app.invoke({"input": "Write a poem about a cat and a dog that are friends."})


for message_chunk, metadata in app.stream({"input": "Write a poem about a cat and a dog that are friends."},
                                          stream_mode=True):
   
    print(message_chunk['output'].content, end='', flush=True)

# %%
response['output']
# Out:
# "In a cozy house, where shadows played,\nLived a whiskered cat and a dog unafraid.\nNot of each other, as tales often tell,\nBut bound by a love, known wonderfully well.\n\nThere was Rufus, the dog, with a tail full of glee,\nA boundless enthusiast, wild and free.\nHe'd gallop and bark, with a wag and a bound,\nThe most loyal of friends that could ever be found.\n\nAnd Luna, the cat, with eyes like the moon,\nA creature of grace, who'd purr a soft tune.\nShe'd stretch in the sun, with a flick of her ear,\nObserving the world, dispelling all fear.\n\nNo ancient old feud, no chase and no hiss,\nJust quiet contentment, and moments of bliss.\nRufus would nudge her with his big, wet nose,\nWhile Luna would knead him, and softly repose.\n\nThey'd share a warm patch by the sun-drenched sill,\nHis rumbly snores, her purring so still.\nA fuzzy brown paw, a white velvet head,\nTogether they'd nap in a shared, comfy bed.\n\nSometimes a playful, slow-motion chase,\nWith Rufus's barks and Luna's 
# ...

# %%
for message_chunk, metadata in app.stream({"input": "Write a poem about a cat and a dog that are friends."},
                                          stream_mode=True):
   
    print(message_chunk['output'].content, end='', flush=True)

# %%
for event in app.stream({"input": "Write a poem about a cat and a dog that are friends."}, stream_mode="updates"):
    # Each event is a dictionary representing state changes
    if "output" in event:
        print(event["output"], end="", flush=True)

# %%
from typing import TypedDict
from langgraph.graph import StateGraph, END
from google import genai

 

def generate_text(prompt: str) -> str:
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=prompt,  # ✅ use string, not {prompt}
    )
    return response.text

class GraphState(TypedDict):
    input: str
    output: str

def generate_text_node(state: GraphState) -> GraphState:
    prompt = state["input"]
    output = generate_text(prompt)
    return {"input": prompt, "output": output}

graph = StateGraph(GraphState)
graph.add_node("generate_text", generate_text_node)
graph.set_entry_point("generate_text")
graph.add_edge("generate_text", END)

app = graph.compile()

# ✅ Normal invoke (non-stream)
# result = app.invoke({"input": "Write a poem about a cat and a dog that are friends."})
# print("\n✅ Final Result:", result["output"])
app.stream ({"input": "Write a poem about a cat and a dog that are friends."}, stream_mode=True)
# Out:
# <generator object Pregel.stream at 0x000001D100D04360>

# %%
for event in app.stream({"input": "Write a poem about a cat and a dog that are friends."}):
    for value in event.values():
        print("Chunk:", value["output"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 for event in app.stream({"input": "Write a poem about a cat and a dog that are friends."}):
#       2     for value in event.values():
#       3         print("Chunk:", value["output"])
#
# File s:\VSCode\myenv\Lib\site-packages\langgraph\pregel\main.py:2674, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, **kwargs)
#    2672 for task in loop.match_cached_writes():
#    2673     loop.output_writes(task.id, task.writes, cached=True)
# -> 2674 for _ in runner.tick(
#    2675     [
#    2676         t
#    2677         for t in loop.tasks.values()
#    2678         if not t.writes and t.id not in loop.skipped_task_ids
#    2679     ],
#    2680     timeout=self.step_timeout,
# ...
