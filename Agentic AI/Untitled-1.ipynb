# %% [markdown]
# # 1. Install Required Packages
#
# Use pip to install the `google-generativeai` package if it is not already installed.

# %%
# !pip install --quiet google-generativeai

# %% [markdown]
# # 2. Import Required Libraries
#
# Import `genai` and `types` from the `google` package, and import `pathlib` for file path operations.

# %%
from google import genai
from google.genai import types
import pathlib

# %% [markdown]
# # 3. Set Up Google Generative AI Client
#
# Initialize the `genai.Client` with your API key. Store the client instance for later use.

# %%
client = genai.Client(api_key="YOUR_API_KEY_HERE")

# %% [markdown]
# # 4. Define Model ID
#
# Set the `MODEL_ID` variable to specify which Gemini model to use for image generation.

# %%
MODEL_ID = "gemini-2.0-flash-preview-image-generation"
